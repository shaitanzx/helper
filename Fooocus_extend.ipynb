# %%
# @markdown # Select profile of Fooocus and start/restart

Fooocus_Profile = "realistic" #@param ["default", "realistic", "anime"]
Fooocus_Theme = "dark" #@param ["dark", "light"]
Tunnel = "gradio" #@param ["gradio", "cloudflared"]

# !pip install pygit2==1.12.2
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# !mkdir /content/Fooocus/batch_images
if Tunnel=='cloudflared':
  # !wget https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
  # !dpkg -i cloudflared-linux-amd64.deb
  # %cd /content/Fooocus
  # !wget -O /content/Fooocus/patcher_tunel.py https://github.com/shaitanzx/Fooocus_extend/raw/main/patcher_tunel.py
  # !python /content/Fooocus/patcher_tunel.py
  # !rm /content/Fooocus/patcher_tunel.py


Memory_patch = True #@param {type:"boolean"}
patch=""
if Memory_patch == True :
    patch="--always-high-vram --all-in-fp16"

GoogleDrive_output = True #@param {type:"boolean"}
output_foder=""
if GoogleDrive_output == True :
    from google.colab import drive
    drive.mount('/content/drive', force_remount=True)
    output_foder="--output-path /content/drive/MyDrive/outputs"
    # !mkdir /content/drive/MyDrive/outputs

# %cd /content
# begin module for synchronization
# !pip install rembg==2.0.53
# !pip install piexif
# !mkdir /content/Fooocus/md_lib
# !wget -O /content/Fooocus/md_lib/__init__.py https://github.com/shaitanzx/Fooocus_extend/raw/main/md_lib/__init__.py
# !wget -O /content/Fooocus/md_lib/cache.py https://github.com/shaitanzx/Fooocus_extend/raw/main/md_lib/cache.py
# !wget -O /content/Fooocus/md_lib/civitai.py https://github.com/shaitanzx/Fooocus_extend/raw/main/md_lib/civitai.py
# !wget -O /content/Fooocus/md_lib/civitai_helper.js https://github.com/shaitanzx/Fooocus_extend/raw/main/md_lib/civitai_helper.js
# !wget -O /content/Fooocus/md_lib/civitai_helper.py https://github.com/shaitanzx/Fooocus_extend/raw/main/md_lib/civitai_helper.py
# !wget -O /content/Fooocus/md_lib/downloader.py https://github.com/shaitanzx/Fooocus_extend/raw/main/md_lib/downloader.py
# !wget -O /content/Fooocus/md_lib/duplicate_check.py https://github.com/shaitanzx/Fooocus_extend/raw/main/md_lib/duplicate_check.py
# !wget -O /content/Fooocus/md_lib/hashes.py https://github.com/shaitanzx/Fooocus_extend/raw/main/md_lib/hashes.py
# !wget -O /content/Fooocus/md_lib/js_action_civitai.py https://github.com/shaitanzx/Fooocus_extend/raw/main/md_lib/js_action_civitai.py
# !wget -O /content/Fooocus/md_lib/md_config.py https://github.com/shaitanzx/Fooocus_extend/raw/main/md_lib/md_config.py
# !wget -O /content/Fooocus/md_lib/model.py https://github.com/shaitanzx/Fooocus_extend/raw/main/md_lib/model.py
# !wget -O /content/Fooocus/md_lib/model_action_civitai.py https://github.com/shaitanzx/Fooocus_extend/raw/main/md_lib/model_action_civitai.py
# !wget -O /content/Fooocus/md_lib/msg_handler.py https://github.com/shaitanzx/Fooocus_extend/raw/main/md_lib/msg_handler.py
# !wget -O /content/Fooocus/md_lib/sections.py https://github.com/shaitanzx/Fooocus_extend/raw/main/md_lib/sections.py
# !wget -O /content/Fooocus/md_lib/templates.py https://github.com/shaitanzx/Fooocus_extend/raw/main/md_lib/templates.py
# !wget -O /content/Fooocus/md_lib/util.py https://github.com/shaitanzx/Fooocus_extend/raw/main/md_lib/util.py

# !wget -O patcher.py https://github.com/shaitanzx/Fooocus_extend/raw/main/patcher.py
# !python /content/patcher.py
# !wget -O patcher2.py https://github.com/shaitanzx/Fooocus_extend/raw/main/patcher2.py
# !python /content/patcher2.py
# !wget -O /content/Fooocus/modules/module_translate.py https://github.com/shaitanzx/Fooocus_extend/raw/main/modules/module_translate.py
# !rm /content/patcher.py
# !rm /content/patcher2.py
# end modulw for synchronization



# %cd /content/Fooocus
#run foocus
if Fooocus_Profile=='default':
  profile=""
if Fooocus_Profile=='realistic':
  profile="--preset realistic"
if Fooocus_Profile=='anime':
  profile="--preset anime"

if Fooocus_Theme=='dark':
  theme="--theme dark"
if Fooocus_Theme=='light':
  theme=""

# !python entry_with_update.py {profile} {theme} --share {patch} {output_foder}
